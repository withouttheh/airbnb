# %%
import numpy as np     
import pandas as pd      
import matplotlib.pyplot as plt   
import seaborn as sns           

# Statistical analysis
import scipy.stats as stats

# Jupyter Notebook magic commands for inline plotting
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
df = pd.read_csv('data/raw/listings.csv')

# %%
df.head()
# Out:
#       id                                               name  host_id  \
# 0   3191  Home in Southern Suburbs · ★4.81 · 1 bedroom ·...     3754
# 1  15007  Home in Cape Town · ★4.82 · 3 bedrooms · 4 bed...    59072
# 2  15068  Rental unit in Cape Town · 3 bedrooms · 5 beds...    59318
# 3  15077  Rental unit in Tableview - Sunset Beach · ★5.0...    59342
# 4  15199  Rental unit in Cape Town · 1 bedroom · 1 bed ·...    59694
#
#   host_name  neighbourhood_group neighbourhood   latitude  longitude  \
# 0  Brigitte                  NaN       Ward 57 -33.947620  18.475990
# 1      Dirk                  NaN       Ward 23 -33.800010  18.460630
# 2     Linda                  NaN       Ward 23 -33.788260  18.459400
# 3     Georg                  NaN        Ward 4 -33.858356  18.490376
# 4     Alexa                  NaN      Ward 115 -33.911150  18.412350
#
#          room_type   price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt   650.0               3                 75  2023-12-23
# 1  Entire home/apt  4029.0               2                 45  2023-12-03
# 2  Entire home/apt  2000.0               4                  0         NaN
# 3     Private room  2377.0               2                  7  2022-06-16
# 4  Entire home/apt  2500.0              14                  2  2016-04-15
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.58                               1               306
# 1               0.37                               3               294
# 2                NaN                               4               354
# 3               0.05                               6                83
# 4               0.02                               1               365
#
#    number_of_reviews_ltm license
# 0                      6     NaN
# 1                      6     NaN
# 2                      0     NaN
# 3                      0     NaN
# 4                      0     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22966 entries, 0 to 22965
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              22966 non-null  int64
#  1   name                            22966 non-null  object
#  2   host_id                         22966 non-null  int64
#  3   host_name                       22962 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   22966 non-null  object
#  6   latitude                        22966 non-null  float64
#  7   longitude                       22966 non-null  float64
#  8   room_type                       22966 non-null  object
#  9   price                           21574 non-null  float64
#  10  minimum_nights                  22966 non-null  int64
#  11  number_of_reviews               22966 non-null  int64
#  12  last_review                     17202 non-null  object
#  13  reviews_per_month               17202 non-null  float64
#  14  calculated_host_listings_count  22966 non-null  int64
#  15  availability_365                22966 non-null  int64
#  16  number_of_reviews_ltm           22966 non-null  int64
#  17  license                         75 non-null     object
# dtypes: float64(5), int64(7), object(6)
# memory usage: 3.2+ MB

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %% [markdown]
# ## Work on Property Type data:

# %%
# create property info dataframe

df_prop_inf = pd.DataFrame()

# %%
# split name column into five columns

df_prop_inf[['property type', 'rating', 'bedrooms', 'beds', 'baths']] = df['name'].str.split(' · ', expand=True)
df_prop_inf.head()
# Out:
#                              property type      rating    bedrooms     beds  \
# 0                 Home in Southern Suburbs       ★4.81   1 bedroom    1 bed
# 1                        Home in Cape Town       ★4.82  3 bedrooms   4 beds
# 2                 Rental unit in Cape Town  3 bedrooms      5 beds  2 baths
# 3  Rental unit in Tableview - Sunset Beach        ★5.0   1 bedroom   2 beds
# 4                 Rental unit in Cape Town   1 bedroom       1 bed   1 bath
#
#        baths
# 0     1 bath
# 1    3 baths
# 2       None
# 3  1.5 baths
# 4       None

# %%
# check if property type column only contains property type data 

percentage_with_in = (df_prop_inf['property type'].str.contains('in').sum() / len(df_prop_inf)) * 100

print("Percentage of rows with 'in' in the 'property type' column:", percentage_with_in)
# Out:
# Percentage of rows with 'in' in the 'property type' column: 100.0

# %%
# isolate property type column for further cleaning by splitting the property type and area

df_prop_inf_clean = df_prop_inf['property type'].str.split(' in ', expand=True)
df_prop_inf_clean.head()
# Out:
#              0                         1     2
# 0         Home          Southern Suburbs  None
# 1         Home                 Cape Town  None
# 2  Rental unit                 Cape Town  None
# 3  Rental unit  Tableview - Sunset Beach  None
# 4  Rental unit                 Cape Town  None

# %%
# check which row does not have null value because the 3rd column should not exist

df_prop_inf_clean[df_prop_inf_clean.notna().all(axis=1)]
# Out:
#                 0             1          2
# 1920  Rental unit  Simon's Town  Cape Town

# %%
# change all 3rd column values to None

df_prop_inf_clean.loc[df_prop_inf_clean[2].notna(), 2] = None
df_prop_inf_clean[2].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
# drop third column

df_prop_inf_clean = df_prop_inf_clean.drop(columns=[2])

# %%
# change 2nd column values to 'Cape Town'

df_prop_inf_clean[1] = 'Cape Town'

# %%
# change column names

df_prop_inf_clean.columns = ['property_type', 'city']
df_prop_inf_clean.head()
# Out:
#   property_type       city
# 0          Home  Cape Town
# 1          Home  Cape Town
# 2   Rental unit  Cape Town
# 3   Rental unit  Cape Town
# 4   Rental unit  Cape Town

# %%
# remove the first column from df

df_prop_inf = df_prop_inf.iloc[:, 1:]

# %%
# add clean property type and city columns to property info df

df_prop_inf['property_type'] = df_prop_inf_clean['property_type']
df_prop_inf['city'] = df_prop_inf_clean['city']

df_prop_inf.head()
# Out:
#        rating    bedrooms     beds      baths property_type       city
# 0       ★4.81   1 bedroom    1 bed     1 bath          Home  Cape Town
# 1       ★4.82  3 bedrooms   4 beds    3 baths          Home  Cape Town
# 2  3 bedrooms      5 beds  2 baths       None   Rental unit  Cape Town
# 3        ★5.0   1 bedroom   2 beds  1.5 baths   Rental unit  Cape Town
# 4   1 bedroom       1 bed   1 bath       None   Rental unit  Cape Town

# %%
df_prop_inf.head()
# Out:
#        rating    bedrooms     beds      baths property_type       city
# 0       ★4.81   1 bedroom    1 bed     1 bath          Home  Cape Town
# 1       ★4.82  3 bedrooms   4 beds    3 baths          Home  Cape Town
# 2  3 bedrooms      5 beds  2 baths       None   Rental unit  Cape Town
# 3        ★5.0   1 bedroom   2 beds  1.5 baths   Rental unit  Cape Town
# 4   1 bedroom       1 bed   1 bath       None   Rental unit  Cape Town

# %% [markdown]
# ## Work on ratings column

# %%
# create ratings dataframe

df_ratings = pd.DataFrame()

# %%
df_ratings.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# populate with ratings column from original dataframe

df_ratings = df_prop_inf['rating']
df_ratings.head()
# Out:
# 0         ★4.81
# 1         ★4.82
# 2    3 bedrooms
# 3          ★5.0
# 4     1 bedroom
# Name: rating, dtype: object

# %%
#if the value does not contain a star, change it to No Rating

df_ratings[df_ratings.str.contains('★') == False ] = 'No rating'

# %%
# check changes 

df_ratings.value_counts()
# Out:
# rating
# No rating    7288
# ★5.0         2939
# ★New         2051
# ★4.67         474
# ★4.80         390
#              ...
# ★3.17           1
# ★2.60           1
# ★4.02           1
# ★3.93           1
# ★2.67           1
# Name: count, Length: 154, dtype: int64

# %%
# if value contains the string New, change it to No Rating

df_ratings[df_ratings.str.contains('New') == True ] = 'No rating'

# %%
# check changes

df_ratings.value_counts()
# Out:
# rating
# No rating    9339
# ★5.0         2939
# ★4.67         474
# ★4.80         390
# ★4.88         388
#              ...
# ★3.17           1
# ★2.60           1
# ★4.02           1
# ★3.93           1
# ★2.67           1
# Name: count, Length: 153, dtype: int64

# %%
# remove the star

df_ratings.loc[df_ratings.str.contains('.')] = df_ratings.str.replace('★', '')

# %%
df_ratings.head()
# Out:
# 0         4.81
# 1         4.82
# 2    No rating
# 3          5.0
# 4    No rating
# Name: rating, dtype: object

# %%
df_ratings.loc[~df_ratings.str.contains('r')] = df_ratings[~df_ratings.str.contains('r')].astype(float)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 df_ratings.loc[~df_ratings.str.contains('r')] = df_ratings[~df_ratings.str.contains('r')].str.strip().astype(float)
#
# File ~\Desktop\Projects\Airbnb\venv\Lib\site-packages\pandas\core\generic.py:1570, in NDFrame.__invert__(self)
#    1566 if not self.size:
#    1567     # inv fails with 0 len
#    1568     return self.copy(deep=False)
# -> 1570 new_data = self._mgr.apply(operator.invert)
#    1571 res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    1572 return res.__finalize__(self, method="__invert__")
#
# File ~\Desktop\Projects\Airbnb\venv\Lib\site-packages\pandas\core\internals\managers.py:361, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     358             kwargs[k] = obj[b.mgr_locs.indexer]
#     360 if callable(f):
# --> 361     applied = b.apply(f, **kwargs)
#     362 else:
#     363     applied = getattr(b, f)(**kwargs)
#
# File ~\Desktop\Projects\Airbnb\venv\Lib\site-packages\pandas\core\internals\blocks.py:393, in Block.apply(self, func, **kwargs)
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# TypeError: bad operand type for unary ~: 'float'

# %%
df_ratings.value_counts()
# Out:
# rating
# No rating    9339
# 5.0          2939
# 4.67          474
# 4.8           390
# 4.88          388
#              ...
# 3.17            1
# 2.6             1
# 4.02            1
# 3.93            1
# 2.67            1
# Name: count, Length: 153, dtype: int64

# %%
df_ratings.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 22966 entries, 0 to 22965
# Series name: rating
# Non-Null Count  Dtype
# --------------  -----
# 22966 non-null  object
# dtypes: object(1)
# memory usage: 179.6+ KB

# %%
df['name'][0]
# Out:
# 'Home in Southern Suburbs · ★4.81 · 1 bedroom · 1 bed · 1 bath'

# %%
df_prop_inf.head()
# Out:
#                              property type      rating    bedrooms     beds  \
# 0                 Home in Southern Suburbs       ★4.81   1 bedroom    1 bed
# 1                        Home in Cape Town       ★4.82  3 bedrooms   4 beds
# 2                 Rental unit in Cape Town  3 bedrooms      5 beds  2 baths
# 3  Rental unit in Tableview - Sunset Beach        ★5.0   1 bedroom   2 beds
# 4                 Rental unit in Cape Town   1 bedroom       1 bed   1 bath
#
#        baths
# 0     1 bath
# 1    3 baths
# 2       None
# 3  1.5 baths
# 4       None

# %%
df_prop_inf['property type'].str.split(' in ', expand=True)[2]
# Out:
# 2
# True     22965
# False        1
# Name: count, dtype: int64

# %%
df_prop_split = df_prop_inf['property type'].str.split(' in ', expand=True)
df_prop_split
# Out:
#                        0                         1     2
# 0                   Home          Southern Suburbs  None
# 1                   Home                 Cape Town  None
# 2            Rental unit                 Cape Town  None
# 3            Rental unit  Tableview - Sunset Beach  None
# 4            Rental unit                 Cape Town  None
# ...                  ...                       ...   ...
# 22961        Rental unit                 Cape Town  None
# 22962        Rental unit                 Cape Town  None
# 22963        Rental unit                 Cape Town  None
# 22964  Bed and breakfast                 Cape Town  None
# 22965        Rental unit                 Cape Town  None
#
# [22966 rows x 3 columns]

# %%
rows_with_nan_in_third_column = df_prop_split[df_prop_split[2].notna()]

# Display rows where the value in the third column is NaN
rows_with_nan_in_third_column
# Out:
#                 0             1          2
# 1920  Rental unit  Simon's Town  Cape Town

# %%
df.head()
# Out:
#       id                                               name  host_id  \
# 0   3191  Home in Southern Suburbs · ★4.81 · 1 bedroom ·...     3754
# 1  15007  Home in Southern Suburbs · ★4.81 · 1 bedroom ·...    59072
# 2  15068  Home in Southern Suburbs · ★4.81 · 1 bedroom ·...    59318
# 3  15077  Home in Southern Suburbs · ★4.81 · 1 bedroom ·...    59342
# 4  15199  Home in Southern Suburbs · ★4.81 · 1 bedroom ·...    59694
#
#   host_name  neighbourhood_group neighbourhood   latitude  longitude  \
# 0  Brigitte                  NaN       Ward 57 -33.947620  18.475990
# 1      Dirk                  NaN       Ward 23 -33.800010  18.460630
# 2     Linda                  NaN       Ward 23 -33.788260  18.459400
# 3     Georg                  NaN        Ward 4 -33.858356  18.490376
# 4     Alexa                  NaN      Ward 115 -33.911150  18.412350
#
#          room_type   price  ...  calculated_host_listings_count  \
# 0  Entire home/apt   650.0  ...                               1
# 1  Entire home/apt  4029.0  ...                               3
# 2  Entire home/apt  2000.0  ...                               4
# 3     Private room  2377.0  ...                               6
# 4  Entire home/apt  2500.0  ...                               1
#
#    availability_365 number_of_reviews_ltm  license  property type  rating  \
# 0               306                     6      NaN           Home   ★4.81
# 1               294                     6      NaN           Home   ★4.81
# 2               354                     0      NaN           Home   ★4.81
# 3                83                     0      NaN           Home   ★4.81
# 4               365                     0      NaN           Home   ★4.81
#
#     bedrooms   beds   baths              area
# 0  1 bedroom  1 bed  1 bath  Southern Suburbs
# 1  1 bedroom  1 bed  1 bath  Southern Suburbs
# 2  1 bedroom  1 bed  1 bath  Southern Suburbs
# 3  1 bedroom  1 bed  1 bath  Southern Suburbs
# 4  1 bedroom  1 bed  1 bath  Southern Suburbs
#
# [5 rows x 24 columns]

# %%
df = df.drop('name', axis=1)

# %%
df.head()
# Out:
#       id  host_id host_name  neighbourhood_group neighbourhood   latitude  \
# 0   3191     3754  Brigitte                  NaN       Ward 57 -33.947620
# 1  15007    59072      Dirk                  NaN       Ward 23 -33.800010
# 2  15068    59318     Linda                  NaN       Ward 23 -33.788260
# 3  15077    59342     Georg                  NaN        Ward 4 -33.858356
# 4  15199    59694     Alexa                  NaN      Ward 115 -33.911150
#
#    longitude        room_type   price  minimum_nights  ...  \
# 0  18.475990  Entire home/apt   650.0               3  ...
# 1  18.460630  Entire home/apt  4029.0               2  ...
# 2  18.459400  Entire home/apt  2000.0               4  ...
# 3  18.490376     Private room  2377.0               2  ...
# 4  18.412350  Entire home/apt  2500.0              14  ...
#
#    calculated_host_listings_count availability_365  number_of_reviews_ltm  \
# 0                               1              306                      6
# 1                               3              294                      6
# 2                               4              354                      0
# 3                               6               83                      0
# 4                               1              365                      0
#
#    license  property type  rating   bedrooms   beds   baths              area
# 0      NaN           Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
# 1      NaN           Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
# 2      NaN           Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
# 3      NaN           Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
# 4      NaN           Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
#
# [5 rows x 23 columns]

# %%
df['ratings'] = df['rating'].str.replace('★', '').astype(float)

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df.columns
# Out:
# Index(['id', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood',
#        'latitude', 'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365',
#        'number_of_reviews_ltm', 'license', 'property_type', 'rating',
#        'bedrooms', 'beds', 'baths', 'area', 'ratings'],
#       dtype='object')

# %%
df.sort_values(by='price', ascending=False)
# Out:
#                         id    host_id     host_name  neighbourhood_group  \
# 5763              25223720  190581790       Pralene                  NaN
# 14395   684763757047711680  123002666  In Residence                  NaN
# 21355  1017762564436049282   59260205   Jean-Claude                  NaN
# 14269   679531837863599355  123002666  In Residence                  NaN
# 5611              24231501  123002666  In Residence                  NaN
# ...                    ...        ...           ...                  ...
# 22852  1051076852921618098   14493823        Susann                  NaN
# 22853  1051081100916269357   14493823        Susann                  NaN
# 22854  1051086993155771519  369636918          Luna                  NaN
# 22855  1051140910221704114  369636918          Luna                  NaN
# 22857  1048593449871787348  492566609       Tawfeeq                  NaN
#
#       neighbourhood   latitude  longitude        room_type     price  \
# 5763         Ward 1 -33.880350  18.588590  Entire home/apt  600850.0
# 14395       Ward 54 -33.935465  18.379730  Entire home/apt  255000.0
# 21355       Ward 54 -33.928879  18.377279  Entire home/apt  242857.0
# 14269       Ward 54 -33.929080  18.375010  Entire home/apt  220000.0
# 5611        Ward 54 -33.934340  18.380710  Entire home/apt  205000.0
# ...             ...        ...        ...              ...       ...
# 22852       Ward 77 -33.919115  18.417192     Private room       NaN
# 22853       Ward 77 -33.919115  18.417192     Private room       NaN
# 22854       Ward 57 -33.950769  18.470332  Entire home/apt       NaN
# 22855       Ward 54 -33.917191  18.390317  Entire home/apt       NaN
# 22857      Ward 115 -33.928849  18.421593  Entire home/apt       NaN
#
#        minimum_nights  ...  availability_365 number_of_reviews_ltm  license  \
# 5763                3  ...               355                     9      NaN
# 14395               3  ...               345                     0      NaN
# 21355               5  ...               180                     0      NaN
# 14269               4  ...               224                     0      NaN
# 5611                3  ...               170                     0      NaN
# ...               ...  ...               ...                   ...      ...
# 22852               2  ...               215                     0      NaN
# 22853               2  ...               232                     0      NaN
# 22854               1  ...                 0                     0      NaN
# 22855               2  ...                 0                     0      NaN
# 22857               2  ...               263                     0      NaN
#
#        property_type  rating   bedrooms   beds   baths              area  \
# 5763            Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
# 14395           Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
# 21355           Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
# 14269           Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
# 5611            Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
# ...              ...     ...        ...    ...     ...               ...
# 22852           Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
# 22853           Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
# 22854           Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
# 22855           Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
# 22857           Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
#
#       ratings
# 5763     4.81
# 14395    4.81
# 21355    4.81
# 14269    4.81
# 5611     4.81
# ...       ...
# 22852    4.81
# 22853    4.81
# 22854    4.81
# 22855    4.81
# 22857    4.81
#
# [22966 rows x 24 columns]

# %%
df.sort_values(by='ratings')
# Out:
#                         id    host_id        host_name  neighbourhood_group  \
# 0                     3191       3754         Brigitte                  NaN
# 15315   740395485000166200  487289339             Nico                  NaN
# 15314   740382511266486363  436883836     Premium Cape                  NaN
# 15313   740380779999019328  484092531            Lance                  NaN
# 15312   740377246220597561  487289339             Nico                  NaN
# ...                    ...        ...              ...                  ...
# 7651              34594639   12945822            Brett                  NaN
# 7650              35019513     287427   Atlantic Point                  NaN
# 7649              35018314     287427   Atlantic Point                  NaN
# 7669              35112172  196861768      John-Edward                  NaN
# 22965  1054361240590217165   31361698  Bespoke Letting                  NaN
#
#       neighbourhood  latitude  longitude        room_type   price  \
# 0           Ward 57 -33.94762   18.47599  Entire home/apt   650.0
# 15315        Ward 1 -33.87955   18.58177  Entire home/apt   682.0
# 15314       Ward 54 -33.96666   18.37576     Private room  1300.0
# 15313      Ward 115 -33.91315   18.41843  Entire home/apt  2900.0
# 15312        Ward 1 -33.87839   18.58358  Entire home/apt   682.0
# ...             ...       ...        ...              ...     ...
# 7651        Ward 55 -33.88424   18.49395  Entire home/apt  2200.0
# 7650       Ward 115 -33.91047   18.41075      Shared room   452.0
# 7649       Ward 115 -33.91059   18.41096     Private room  2344.0
# 7669        Ward 55 -33.89017   18.51354  Entire home/apt  3591.0
# 22965      Ward 115 -33.92390   18.42157  Entire home/apt  1560.0
#
#        minimum_nights  ...  availability_365 number_of_reviews_ltm  license  \
# 0                   3  ...               306                     6      NaN
# 15315               2  ...               356                     8      NaN
# 15314               3  ...                 0                     1      NaN
# 15313               3  ...               304                    36      NaN
# 15312               2  ...               354                     6      NaN
# ...               ...  ...               ...                   ...      ...
# 7651                3  ...                91                    12      NaN
# 7650                1  ...                 8                    15      NaN
# 7649                1  ...                 2                     2      NaN
# 7669                1  ...               262                    43      NaN
# 22965               3  ...               135                     0      NaN
#
#        property_type  rating   bedrooms   beds   baths              area  \
# 0               Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
# 15315           Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
# 15314           Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
# 15313           Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
# 15312           Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
# ...              ...     ...        ...    ...     ...               ...
# 7651            Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
# 7650            Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
# 7649            Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
# 7669            Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
# 22965           Home   ★4.81  1 bedroom  1 bed  1 bath  Southern Suburbs
#
#       ratings
# 0        4.81
# 15315    4.81
# 15314    4.81
# 15313    4.81
# 15312    4.81
# ...       ...
# 7651     4.81
# 7650     4.81
# 7649     4.81
# 7669     4.81
# 22965    4.81
#
# [22966 rows x 24 columns]

# %%
# Define the function and the integration limits
f = lambda x: x
a = 0
b = 1
# Generate random points
N = 10000
x = np.random.uniform(a, b, N)
y = np.random.uniform(a, b, N)
# Count the number of points under the curve
under_curve = np.where(y < f(x), 1, 0)
M = np.sum(under_curve)
# Estimate the value of the integral
I = (b - a) * (M / N)
# Plot the points and the function curve
plt.scatter(x, y, c=under_curve, cmap='viridis')
plt.plot(np.linspace(a, b, 100), f(np.linspace(a, b, 100)), 'r')
plt.show()
print('Estimated value of the integral:', I)
# Out:
# Estimated value of the integral: 0.503
